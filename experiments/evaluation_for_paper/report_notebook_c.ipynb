# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from create_plots import import_dataframe, show_stats, show_plots, quality_stats_single

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %% [markdown]
# Select the dataset name to evaluate:

# %%
result_files = [
    "C_20_1_results.csv"
]
#indices go from 0 to 0

filename = result_files[0]

# %%
print("This evaluation is for: " + filename)
# Out:
# This evaluation is for: C_20_1_results.csv

# %%
df = import_dataframe("result_files/"+filename)
filename = filename.split("_results.csv")[0]

df_normal = df.query('use_partitioned_msa == True')
df_unpartitioned = df.query('use_partitioned_msa == False')

print(df.columns)
# Out:
# Index(['name', 'n_taxa', 'n_trees', 'n_reticulations', 'msa_size',
#        'sites_per_tree', 'sampling_type', 'simulation_type', 'celine_params',
#        'brlen_scaler', 'seqgen_params', 'near_zero_branches_raxml',
#        'n_equal_tree_pairs', 'true_network_weirdness', 'true_network_path',
#        'fixed_reticulation_prob', 'runtime_raxml', 'inferred_network_path',
#        'likelihood_type', 'brlen_linkage_type', 'start_type', 'timeout',
#        'n_random_start_networks', 'n_parsimony_start_networks',
#        'runtime_inference', 'use_partitioned_msa', 'n_reticulations_inferred',
#        'bic_true', 'logl_true', 'aic_true', 'aicc_true', 'bic_inferred',
#        'logl_inferred', 'aic_inferred', 'aicc_inferred', 'bic_raxml',
#        'logl_raxml', 'aic_raxml', 'aicc_raxml', 'rf_absolute_raxml',
#        'rf_relative_raxml', 'rf_absolute_inferred', 'rf_relative_inferred',
#        'msa_patterns', 'unrooted_softwired_network_distance',
# ...

# %% [markdown]
# # Original Simulated Dataset Statistics

# %%
show_stats(filename, df_normal)
# Out:
# Total number of datasets: 50

# %% [markdown]
# # Evaluation starting from raxml-ng best tree prob

# %%
quality_stats_single(filename+"_normal", df_normal)
quality_stats_single(filename+"_unpartitioned", df_unpartitioned)
show_plots(filename+"_normal", df_normal)
show_plots(filename+"_unpartitioned", df_unpartitioned)
# Out:
# +----------------------------------+----------------+
# |          C_20_1_normal           | LhType.AVERAGE |
# +----------------------------------+----------------+
# |   Inferred BIC better or equal   |  23 (46.00 %)  |
# |   Inferred AIC better or equal   |  21 (42.00 %)  |
# |  Inferred AICc better or equal   |  21 (42.00 %)  |
# |        Inferred BIC worse        |  27 (54.00 %)  |
# |        Inferred AIC worse        |  29 (58.00 %)  |
# |       Inferred AICc worse        |  29 (58.00 %)  |
# |  Inferred logl better or equal   |  21 (42.00 %)  |
# |       Inferred logl worse        |  29 (58.00 %)  |
# |  Inferred n_reticulations less   |   3 (6.00 %)   |
# |  Inferred n_reticulations equal  |  47 (94.00 %)  |
# |  Inferred n_reticulations more   |   0 (0.00 %)   |
# | Unrooted softwired distance zero |  24 (48.00 %)  |
# |           Good result            |  39 (78.00 %)  |
# |           Okay result            |  10 (20.00 %)  |
# ...
