# %%
from subnotebook import Return, default_value

# %%
default_value(prefix="small_network")

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
from create_plots import import_dataframe, show_stats, show_plots

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

df = import_dataframe(prefix)
print(df.columns)
# Out:
# Index(['name', 'n_taxa', 'n_trees', 'n_reticulations', 'msa_size',
#        'sampling_type', 'simulation_type', 'celine_params', 'seqgen_params',
#        'near_zero_branches_raxml', 'n_equal_tree_pairs',
#        'true_network_weirdness', 'true_network_path', 'inferred_network_path',
#        'likelihood_type', 'brlen_linkage_type', 'start_type', 'timeout',
#        'n_random_start_networks', 'n_parsimony_start_networks',
#        'runtime_inference', 'n_reticulations_inferred', 'bic_true',
#        'logl_true', 'bic_inferred', 'logl_inferred', 'bic_raxml', 'logl_raxml',
#        'rf_absolute_raxml', 'rf_relative_raxml', 'rf_absolute_inferred',
#        'rf_relative_inferred', 'hardwired_cluster_distance',
#        'softwired_cluster_distance', 'displayed_trees_distance',
#        'tripartition_distance', 'nested_labels_distance',
#        'path_multiplicity_distance', 'bic_diff', 'logl_diff'],
#       dtype='object')

# %% [markdown]
# # Simulated Dataset Statistics

# %%
show_stats(df)

# %% [markdown]
# # Evaluation of all Results combined

# %%
show_plots(df)
# Out:
# +--------------------------------+---------------------------+----------------------------+----------------------------+
# |                                |   LikelihoodType.AVERAGE  |    LikelihoodType.BEST     |          Overall           |
# +--------------------------------+---------------------------+----------------------------+----------------------------+
# |  Inferred BIC better or equal  | 490 (96.45669291338582 %) | 487 (95.86614173228347 %)  | 977 (96.16141732283465 %)  |
# |       Inferred BIC worse       |  18 (3.543307086614173 %) |  21 (4.133858267716535 %)  |  39 (3.838582677165354 %)  |
# | Inferred logl better or equal  | 208 (40.94488188976378 %) | 244 (48.031496062992126 %) | 452 (44.488188976377955 %) |
# |      Inferred logl worse       | 300 (59.05511811023622 %) | 264 (51.968503937007874 %) | 564 (55.511811023622045 %) |
# | Inferred n_reticulations less  | 456 (89.76377952755905 %) | 456 (89.76377952755905 %)  | 912 (89.76377952755905 %)  |
# | Inferred n_reticulations equal | 52 (10.236220472440944 %) | 52 (10.236220472440944 %)  | 104 (10.236220472440944 %) |
# | Inferred n_reticulations more  |         0 (0.0 %)         |         0 (0.0 %)          |         0 (0.0 %)          |
# +--------------------------------+---------------------------+----------------------------+----------------------------+

# %% [markdown]
# # Evaluation of all results combined, non-weird networks only

# %%
df_nonweird = df.query('true_network_weirdness == 0.0')
show_stats(df_nonweird)
show_plots(df_nonweird)
# Out:
# +--------------------------------+---------------------------+---------------------------+---------------------------+
# |                                |   LikelihoodType.AVERAGE  |    LikelihoodType.BEST    |          Overall          |
# +--------------------------------+---------------------------+---------------------------+---------------------------+
# |  Inferred BIC better or equal  | 271 (94.09722222222223 %) | 267 (92.70833333333333 %) | 538 (93.40277777777777 %) |
# |       Inferred BIC worse       |  17 (5.902777777777778 %) |  21 (7.291666666666667 %) |  38 (6.597222222222222 %) |
# | Inferred logl better or equal  | 96 (33.333333333333336 %) | 106 (36.80555555555556 %) | 202 (35.06944444444444 %) |
# |      Inferred logl worse       | 192 (66.66666666666667 %) | 182 (63.19444444444444 %) | 374 (64.93055555555556 %) |
# | Inferred n_reticulations less  | 240 (83.33333333333333 %) | 240 (83.33333333333333 %) | 480 (83.33333333333333 %) |
# | Inferred n_reticulations equal | 48 (16.666666666666668 %) | 48 (16.666666666666668 %) | 96 (16.666666666666668 %) |
# | Inferred n_reticulations more  |         0 (0.0 %)         |         0 (0.0 %)         |         0 (0.0 %)         |
# +--------------------------------+---------------------------+---------------------------+---------------------------+

# %%
Return(None)
