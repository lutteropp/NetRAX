# %%
# %matplotlib inline
from subnotebook import run_nb, display_nb

# %%
run_nb('evaluate_subnotebook.ipynb', prefix='small_network')
# Out:
# This evaluation is for: small_network
# Index(['name', 'n_taxa', 'n_trees', 'n_reticulations', 'msa_size',
#        'sampling_type', 'simulation_type', 'celine_params', 'seqgen_params',
#        'near_zero_branches_raxml', 'n_equal_tree_pairs',
#        'true_network_weirdness', 'true_network_path', 'inferred_network_path',
#        'likelihood_type', 'brlen_linkage_type', 'start_type', 'timeout',
#        'n_random_start_networks', 'n_parsimony_start_networks',
#        'runtime_inference', 'n_reticulations_inferred', 'bic_true',
#        'logl_true', 'bic_inferred', 'logl_inferred', 'bic_raxml', 'logl_raxml',
#        'rf_absolute_raxml', 'rf_relative_raxml', 'rf_absolute_inferred',
#        'rf_relative_inferred', 'hardwired_cluster_distance',
#        'softwired_cluster_distance', 'displayed_trees_distance',
#        'tripartition_distance', 'nested_labels_distance',
#        'path_multiplicity_distance', 'bic_diff', 'logl_diff'],
#       dtype='object')
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     129 (89.58 %)      |    126 (87.50 %)    | 255 (88.54 %) |
# |       Inferred BIC worse       |      15 (10.42 %)      |     18 (12.50 %)    |  33 (11.46 %) |
# | Inferred logl better or equal  |      41 (28.47 %)      |     45 (31.25 %)    |  86 (29.86 %) |
# |      Inferred logl worse       |     103 (71.53 %)      |     99 (68.75 %)    | 202 (70.14 %) |
# | Inferred n_reticulations less  |     123 (85.42 %)      |    123 (85.42 %)    | 246 (85.42 %) |
# | Inferred n_reticulations equal |      21 (14.58 %)      |     21 (14.58 %)    |  42 (14.58 %) |
# | Inferred n_reticulations more  |       0 (0.00 %)       |      0 (0.00 %)     |   0 (0.00 %)  |
# +--------------------------------+------------------------+---------------------+---------------+
#
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     252 (99.21 %)      |    251 (98.82 %)    | 503 (99.02 %) |
# |       Inferred BIC worse       |       2 (0.79 %)       |      3 (1.18 %)     |   5 (0.98 %)  |
# | Inferred logl better or equal  |     109 (42.91 %)      |    131 (51.57 %)    | 240 (47.24 %) |
# |      Inferred logl worse       |     145 (57.09 %)      |    123 (48.43 %)    | 268 (52.76 %) |
# | Inferred n_reticulations less  |     225 (88.58 %)      |    225 (88.58 %)    | 450 (88.58 %) |
# | Inferred n_reticulations equal |      29 (11.42 %)      |     29 (11.42 %)    |  58 (11.42 %) |
# | Inferred n_reticulations more  |       0 (0.00 %)       |      0 (0.00 %)     |   0 (0.00 %)  |
# +--------------------------------+------------------------+---------------------+---------------+

# %%
run_nb('evaluate_subnotebook.ipynb', prefix='small_network_uniform')
# Out:
# This evaluation is for: small_network_uniform
# Index(['name', 'n_taxa', 'n_trees', 'n_reticulations', 'msa_size',
#        'sampling_type', 'simulation_type', 'celine_params', 'seqgen_params',
#        'near_zero_branches_raxml', 'n_equal_tree_pairs',
#        'true_network_weirdness', 'true_network_path', 'inferred_network_path',
#        'likelihood_type', 'brlen_linkage_type', 'start_type', 'timeout',
#        'n_random_start_networks', 'n_parsimony_start_networks',
#        'runtime_inference', 'n_reticulations_inferred', 'bic_true',
#        'logl_true', 'bic_inferred', 'logl_inferred', 'bic_raxml', 'logl_raxml',
#        'rf_absolute_raxml', 'rf_relative_raxml', 'rf_absolute_inferred',
#        'rf_relative_inferred', 'hardwired_cluster_distance',
#        'softwired_cluster_distance', 'displayed_trees_distance',
#        'tripartition_distance', 'nested_labels_distance',
#        'path_multiplicity_distance', 'bic_diff', 'logl_diff'],
#       dtype='object')
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     127 (88.19 %)      |    126 (87.50 %)    | 253 (87.85 %) |
# |       Inferred BIC worse       |      17 (11.81 %)      |     18 (12.50 %)    |  35 (12.15 %) |
# | Inferred logl better or equal  |      42 (29.17 %)      |     43 (29.86 %)    |  85 (29.51 %) |
# |      Inferred logl worse       |     102 (70.83 %)      |    101 (70.14 %)    | 203 (70.49 %) |
# | Inferred n_reticulations less  |     112 (77.78 %)      |    112 (77.78 %)    | 224 (77.78 %) |
# | Inferred n_reticulations equal |      32 (22.22 %)      |     32 (22.22 %)    |  64 (22.22 %) |
# | Inferred n_reticulations more  |       0 (0.00 %)       |      0 (0.00 %)     |   0 (0.00 %)  |
# +--------------------------------+------------------------+---------------------+---------------+
#
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     253 (98.83 %)      |    252 (98.44 %)    | 505 (98.63 %) |
# |       Inferred BIC worse       |       3 (1.17 %)       |      4 (1.56 %)     |   7 (1.37 %)  |
# | Inferred logl better or equal  |      97 (37.89 %)      |    104 (40.62 %)    | 201 (39.26 %) |
# |      Inferred logl worse       |     159 (62.11 %)      |    152 (59.38 %)    | 311 (60.74 %) |
# | Inferred n_reticulations less  |     214 (83.59 %)      |    214 (83.59 %)    | 428 (83.59 %) |
# | Inferred n_reticulations equal |      42 (16.41 %)      |     42 (16.41 %)    |  84 (16.41 %) |
# | Inferred n_reticulations more  |       0 (0.00 %)       |      0 (0.00 %)     |   0 (0.00 %)  |
# +--------------------------------+------------------------+---------------------+---------------+

# %%
run_nb('evaluate_subnotebook.ipynb', prefix='small_network_uniform_larger_msa')
# Out:
# This evaluation is for: small_network_uniform_larger_msa
# Index(['name', 'n_taxa', 'n_trees', 'n_reticulations', 'msa_size',
#        'sampling_type', 'simulation_type', 'celine_params', 'seqgen_params',
#        'near_zero_branches_raxml', 'n_equal_tree_pairs',
#        'true_network_weirdness', 'true_network_path', 'inferred_network_path',
#        'likelihood_type', 'brlen_linkage_type', 'start_type', 'timeout',
#        'n_random_start_networks', 'n_parsimony_start_networks',
#        'runtime_inference', 'n_reticulations_inferred', 'bic_true',
#        'logl_true', 'bic_inferred', 'logl_inferred', 'bic_raxml', 'logl_raxml',
#        'rf_absolute_raxml', 'rf_relative_raxml', 'rf_absolute_inferred',
#        'rf_relative_inferred', 'hardwired_cluster_distance',
#        'softwired_cluster_distance', 'displayed_trees_distance',
#        'tripartition_distance', 'nested_labels_distance',
#        'path_multiplicity_distance', 'bic_diff', 'logl_diff'],
#       dtype='object')
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     108 (73.97 %)      |    110 (75.34 %)    | 218 (74.66 %) |
# |       Inferred BIC worse       |      38 (26.03 %)      |     36 (24.66 %)    |  74 (25.34 %) |
# | Inferred logl better or equal  |      45 (30.82 %)      |     48 (32.88 %)    |  93 (31.85 %) |
# |      Inferred logl worse       |     101 (69.18 %)      |     98 (67.12 %)    | 199 (68.15 %) |
# | Inferred n_reticulations less  |      89 (60.96 %)      |     95 (65.07 %)    | 184 (63.01 %) |
# | Inferred n_reticulations equal |      53 (36.30 %)      |     49 (33.56 %)    | 102 (34.93 %) |
# | Inferred n_reticulations more  |       4 (2.74 %)       |      2 (1.37 %)     |   6 (2.05 %)  |
# +--------------------------------+------------------------+---------------------+---------------+
#
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     248 (96.88 %)      |    249 (97.27 %)    | 497 (97.07 %) |
# |       Inferred BIC worse       |       8 (3.12 %)       |      7 (2.73 %)     |  15 (2.93 %)  |
# | Inferred logl better or equal  |     125 (48.83 %)      |    134 (52.34 %)    | 259 (50.59 %) |
# |      Inferred logl worse       |     131 (51.17 %)      |    122 (47.66 %)    | 253 (49.41 %) |
# | Inferred n_reticulations less  |     175 (68.36 %)      |    175 (68.36 %)    | 350 (68.36 %) |
# | Inferred n_reticulations equal |      80 (31.25 %)      |     81 (31.64 %)    | 161 (31.45 %) |
# | Inferred n_reticulations more  |       1 (0.39 %)       |      0 (0.00 %)     |   1 (0.20 %)  |
# +--------------------------------+------------------------+---------------------+---------------+

# %%
run_nb('evaluate_subnotebook.ipynb', prefix='medium_network_norandom')
# Out:
# This evaluation is for: medium_network_norandom
# Index(['name', 'n_taxa', 'n_trees', 'n_reticulations', 'msa_size',
#        'sampling_type', 'simulation_type', 'celine_params', 'seqgen_params',
#        'near_zero_branches_raxml', 'n_equal_tree_pairs',
#        'true_network_weirdness', 'true_network_path', 'inferred_network_path',
#        'likelihood_type', 'brlen_linkage_type', 'start_type', 'timeout',
#        'n_random_start_networks', 'n_parsimony_start_networks',
#        'runtime_inference', 'n_reticulations_inferred', 'bic_true',
#        'logl_true', 'bic_inferred', 'logl_inferred', 'bic_raxml', 'logl_raxml',
#        'hardwired_cluster_distance', 'softwired_cluster_distance',
#        'displayed_trees_distance', 'tripartition_distance',
#        'nested_labels_distance', 'path_multiplicity_distance', 'bic_diff',
#        'logl_diff'],
#       dtype='object')
# +--------------------------------+------------------------+---------------------+---------------+
# |                                | LikelihoodType.AVERAGE | LikelihoodType.BEST |    Overall    |
# +--------------------------------+------------------------+---------------------+---------------+
# |  Inferred BIC better or equal  |     182 (91.00 %)      |    175 (87.50 %)    | 357 (89.25 %) |
# |       Inferred BIC worse       |      18 (9.00 %)       |     25 (12.50 %)    |  43 (10.75 %) |
# | Inferred logl better or equal  |      81 (40.50 %)      |     80 (40.00 %)    | 161 (40.25 %) |
# |      Inferred logl worse       |     119 (59.50 %)      |    120 (60.00 %)    | 239 (59.75 %) |
# | Inferred n_reticulations less  |     174 (87.00 %)      |    179 (89.50 %)    | 353 (88.25 %) |
# | Inferred n_reticulations equal |      26 (13.00 %)      |     21 (10.50 %)    |  47 (11.75 %) |
# | Inferred n_reticulations more  |       0 (0.00 %)       |      0 (0.00 %)     |   0 (0.00 %)  |
# +--------------------------------+------------------------+---------------------+---------------+
#
# No data found for StartType.RANDOM
