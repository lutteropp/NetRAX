# %%
# %matplotlib inline
from subnotebook import run_nb, display_nb

# %%
run_nb('evaluate_subnotebook.ipynb', prefix='small_network')
# Out:
# Inferred BIC better or equal: 977
# Inferred BIC worse: 39
# Inferred loglh better or equal: 452
# Inferred loglh worse: 564
#
# Inferred n_reticulations less: 912
# Inferred n_reticulations equal: 104
# Inferred n_reticulations more: 0
